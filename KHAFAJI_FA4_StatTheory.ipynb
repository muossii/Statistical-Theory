# %%
normal = [67, 70, 63, 65, 68, 
          60, 70, 64, 69, 61, 
          66, 65, 71, 62, 66, 
          68, 64, 67, 62, 66, 
          65, 63, 66, 65, 63,
          69, 62, 67, 59, 66, 
          65, 63, 65, 60, 67, 
          64, 68, 61, 69, 65, 
          62, 67, 70, 64, 63, 
          68, 64, 65, 61, 66
         ]

skewed_right = [31, 43, 30, 30, 38, 
                26, 29, 55, 46, 26, 
                29, 57, 34, 34, 36, 
                40, 28, 26, 66, 63, 
                30, 33, 24, 35, 34, 
                40, 24, 29, 24, 27, 
                35, 33, 75, 38, 34, 
                85, 29, 40, 41, 35, 
                26, 34, 19, 23, 28, 
                26, 31, 25, 22, 28
               ]

skewed_left = [102, 55, 70, 95, 73,
               79, 60, 73, 89, 85,
               72, 92, 76, 93, 76, 
               97, 10, 70, 85, 25, 
               83, 58, 10, 93, 82,
               87, 104, 75, 80, 66, 
               93, 90, 84, 73, 98, 
               79, 35, 71, 90, 71,
               63, 58, 82, 72, 93,
               44, 65, 77, 81, 77
              ]

uniform = [12.1, 12.1, 12.4, 12.1, 12.1,
           12.2, 12.2, 12.2, 11.9, 12.2, 
           12.3, 12.3, 11.7, 12.3, 12.3, 
           12.4, 12.4, 12.1, 12.4, 12.4,
           12.5, 11.8, 12.5, 12.5, 12.5, 
           11.6, 11.6, 12.0, 11.6, 11.6, 
           11.7, 12.3, 11.7, 11.7, 11.7,
           11.8, 12.5, 11.8, 11.8, 11.8,
           11.9, 11.9, 11.9, 12.2, 11.9,
           12.0, 11.9, 12.0, 12.0, 12.0
          ]

# %%
#create function for moment generation
def moment(data, rth_moment, about_n = 0):
    
    n = len(data)
    moment_sum = 0
    
    for value in data:
        moment_sum += (value - about_n)**rth_moment
        
    return moment_sum/n

# %% [markdown]
# 1. Moments about 0

# %%
# moments of normal

# first moment
mean_normal = moment(normal, 1)
print("The first moment of the normal data about 0 is:", mean_normal )

# 2nd moment
scnd_moment_0_normal = moment(normal, 2)
print("The second moment of the normal data about 0 is:", scnd_moment_0_normal )

# 3rd moment
trd_moment_0_normal = moment(normal, 3)
print("The third moment of the normal data about 0 is:", trd_moment_0_normal )


# 4th moment
frt_moment_0_normal = moment(normal, 4)
print("The fourth moment of the normal data about 0 is:", frt_moment_0_normal,"\n" )




## moments of right skewed

#first moment
mean_rskewed = moment(skewed_right, 1)

print("The first moment of the right skewed data about 0 is:", mean_rskewed )

# 2nd moment

scnd_moment_0_rskewed = moment(skewed_right, 2)
print("The second moment of the right skewed data about 0 is:", scnd_moment_0_rskewed )


# 3rd moment

trd_moment_0_rskewed = moment(skewed_right, 3)
print("The third moment of the right skewed data about 0 is:", trd_moment_0_rskewed )

# 4th moment

frt_moment_0_rskewed = moment(skewed_right, 4)
print("The fourth moment of the right skewed data about 0 is:", frt_moment_0_rskewed,"\n" )




## moments of left skewed

#first moment
mean_lskewed = moment(skewed_left, 1)
print("The first moment of the left skewed data about 0 is:", mean_lskewed )


# 2nd moment

scnd_moment_0_lskewed = moment(skewed_left, 2)
print("The second moment of the left skewed data about 0 is:", scnd_moment_0_lskewed )

# 3rd moment

trd_moment_0_lskewed = moment(skewed_left, 3)
print("The third moment of the left skewed data about 0 is:", trd_moment_0_lskewed )

# 4th moment

frt_moment_0_lskewed = moment(skewed_left, 4)
print("The fourth moment of the left skewed data about 0 is:", frt_moment_0_lskewed,"\n" )




## moments of uniform data

#first moment
mean_unif = moment(uniform, 1)
print("The first moment of the uniform data about 0 is:", mean_unif )

# 2nd moment

scnd_moment_0_unif = moment(uniform, 2)
print("The second moment of the uniform data about 0 is:", scnd_moment_0_unif )

# 3rd moment

trd_moment_0_unif = moment(uniform, 3)
print("The third moment of the uniform data about 0 is:", trd_moment_0_unif )

# 4th moment

frt_moment_0_unif = moment(uniform, 4)
print("The fourth moment of the uniform data about 0 is:", frt_moment_0_unif,"\n" )
# Out:
# The first moment of the normal data about 0 is: 65.12
# The second moment of the normal data about 0 is: 4248.92
# The third moment of the normal data about 0 is: 277770.92
# The fourth moment of the normal data about 0 is: 18194173.64
#
# The first moment of the right skewed data about 0 is: 35.48
# The second moment of the right skewed data about 0 is: 1437.72
# The third moment of the right skewed data about 0 is: 68292.44
# The fourth moment of the right skewed data about 0 is: 3797594.04
#
# The first moment of the left skewed data about 0 is: 74.22
# The second moment of the left skewed data about 0 is: 5929.1
# The third moment of the left skewed data about 0 is: 489972.18
# The fourth moment of the left skewed data about 0 is: 41459479.58
#
# The first moment of the uniform data about 0 is: 12.056000000000001
# The second moment of the uniform data about 0 is: 145.42600000000002
# The third moment of the uniform data about 0 is: 1755.1577600000005
# ...

# %% [markdown]
# Moments about the mean

# %%
# moments of normal

# first moment
frst_moment_mean_normal = moment(normal, 1, mean_normal)
print("The first moment of the normal data about the mean is:", frst_moment_mean_normal )


# 2nd moment
scnd_moment_mean_normal = moment(normal, 2, mean_normal)
print("The second moment of the normal data about the mean is:", scnd_moment_mean_normal )


# 3rd moment
trd_moment_mean_normal = moment(normal, 3, mean_normal)
print("The third moment of the normal data about the mean is:", trd_moment_mean_normal )

# 4th moment
frt_moment_mean_normal = moment(normal, 4, mean_normal)
print("The fourth moment of the normal data about the mean is:", frt_moment_mean_normal,"\n" )




## moments of right skewed


#first moment
frst_moment_mean_rskewed = moment(skewed_right, 1, mean_rskewed)
print("The first moment of the right skewed data about the mean is:", frst_moment_mean_rskewed )


# 2nd moment

scnd_moment_mean_rskewed = moment(skewed_right, 2, mean_rskewed)
print("The second moment of the right skewed data about the mean is:", scnd_moment_mean_rskewed )


# 3rd moment

trd_moment_mean_rskewed = moment(skewed_right, 3, mean_rskewed)
print("The third moment of the right skewed data about the mean is:", trd_moment_mean_rskewed )


# 4th moment

frt_moment_mean_rskewed = moment(skewed_right, 4, mean_rskewed)
print("The fourth moment of the right skewed data about the mean is:", frt_moment_mean_rskewed,"\n" )


## moments of left skewed


#first moment
frst_moment_mean_lskewed = moment(skewed_left, 1, mean_lskewed)
print("The first moment of the left skewed  data about the mean is:", frst_moment_mean_lskewed )


# 2nd moment

scnd_moment_mean_lskewed = moment(skewed_left, 2, mean_lskewed)
print("The second moment of the left skewed  data about the mean is:", scnd_moment_mean_lskewed )


# 3rd moment

trd_moment_mean_lskewed = moment(skewed_left, 3, mean_lskewed)
print("The third moment of the left skewed data about the mean is:", trd_moment_mean_lskewed )


# 4th moment

frt_moment_mean_lskewed = moment(skewed_left, 4, mean_lskewed)
print("The fourth moment of the left skewed  data about the mean is:", frt_moment_mean_lskewed,"\n" )



## moments of uniform data



#first moment
frst_moment_mean_unif = moment(uniform, 1, mean_unif)
print("The first moment of the uniform data about the mean is:", frst_moment_mean_unif )


# 2nd moment

scnd_moment_mean_unif = moment(uniform, 2, mean_unif)
print("The second moment of the uniform data about the mean is:", scnd_moment_mean_unif )


# 3rd moment

trd_moment_mean_unif = moment(uniform, 3, mean_unif)
print("The third moment of the uniform data about the mean is:", trd_moment_mean_unif )


# 4th moment

frt_moment_mean_unif = moment(uniform, 4, mean_unif)
print("The fourth moment of the uniform data about the mean is:", frt_moment_mean_unif,"\n" )
# Out:
# The first moment of the normal data about the mean is: -4.547473508864641e-15
# The second moment of the normal data about the mean is: 8.305600000000007
# The third moment of the normal data about the mean is: -0.47174400000011113
# The fourth moment of the normal data about the mean is: 160.94862592000004
#
# The first moment of the right skewed data about the mean is: 4.121147867408581e-15
# The second moment of the right skewed data about the mean is: 178.88960000000006
# The third moment of the right skewed data about the mean is: 4588.1283840000015
# The fourth moment of the right skewed data about the mean is: 210642.8834355201
#
# The first moment of the left skewed  data about the mean is: 1.1368683772161603e-15
# The second moment of the left skewed  data about the mean is: 420.49159999999983
# The third moment of the left skewed data about the mean is: -12503.395104000001
# The fourth moment of the left skewed  data about the mean is: 928779.6545883201
#
# ...

# %% [markdown]
# Moments about 75

# %%
# moments of normal




# first moment
frst_moment_75_normal = moment(normal, 1, 75)
print("The first moment of the normal data about 75 is:", frst_moment_75_normal )

# 2nd moment
scnd_moment_75_normal = moment(normal, 2, 75)
print("The second moment of the normal data about 75 is:", scnd_moment_75_normal )


# 3rd moment
trd_moment_75_normal = moment(normal, 3, 75)
print("The third moment of the normal data about 75 is:", trd_moment_75_normal )


# 4th moment
frt_moment_75_normal = moment(normal, 4, 75)
print("The fourth moment of the normal data about 75 is:", frt_moment_75_normal,"\n" )


## moments of right skewed




#first moment
frst_moment_75_rskewed = moment(skewed_right, 1, 75)
print("The first moment of the right skewed data about 75 is:", frst_moment_75_rskewed )


# 2nd moment

scnd_moment_75_rskewed = moment(skewed_right, 2, 75)
print("The second moment of the right skewed data about 75 is:", scnd_moment_75_rskewed )


# 3rd moment

trd_moment_75_rskewed = moment(skewed_right, 3, 75)
print("The third moment of the right skewed data about 75 is:", trd_moment_75_rskewed )


# 4th moment
frt_moment_75_rskewed = moment(skewed_right, 4, 75)
print("The fourth moment of the right skewed data about 75 is:", frt_moment_75_rskewed,"\n" )


## moments of left skewed



#first moment
frst_moment_75_lskewed = moment(skewed_left, 1, 75)
print("The first moment of the left skewed data about 75 is:", frst_moment_75_lskewed )


# 2nd moment

scnd_moment_75_lskewed = moment(skewed_left, 2, 75)
print("The second moment of the left skewed data about 75 is:", scnd_moment_75_lskewed )


# 3rd moment

trd_moment_75_lskewed = moment(skewed_left, 3, 75)
print("The third moment of the left skewed data about 75 is:", trd_moment_75_lskewed )


# 4th moment

frt_moment_75_lskewed = moment(skewed_left, 4, 75)
print("The fourth moment of the left skewed data about 75 is:", frt_moment_75_lskewed,"\n" )


## moments of uniform data



#first moment
frst_moment_75_unif = moment(uniform, 1, 75)
print("The first moment of the uniform data about 75 is:", frst_moment_75_unif )


# 2nd moment

scnd_moment_75_unif = moment(uniform, 2, 75)
print("The second moment of the uniform data about 75 is:", scnd_moment_75_unif )


# 3rd moment

trd_moment_75_unif = moment(uniform, 3, 75)
print("The third moment of the uniform data about 75 is:", trd_moment_75_unif )


# 4th moment

frt_moment_75_unif = moment(uniform, 4, 75)
print("The fourth moment of the uniform data about 75 is:", frt_moment_75_unif,"\n" )
# Out:
# The first moment of the normal data about 75 is: -9.88
# The second moment of the normal data about 75 is: 105.92
# The third moment of the normal data about 75 is: -1211.08
# The fourth moment of the normal data about 75 is: 14572.64
#
# The first moment of the right skewed data about 75 is: -39.52
# The second moment of the right skewed data about 75 is: 1740.72
# The third moment of the right skewed data about 75 is: -78344.56
# The fourth moment of the right skewed data about 75 is: 3601037.04
#
# The first moment of the left skewed data about 75 is: -0.78
# The second moment of the left skewed data about 75 is: 421.1
# The third moment of the left skewed data about 75 is: -13487.82
# The fourth moment of the left skewed data about 75 is: 969325.58
#
# The first moment of the uniform data about 75 is: -62.943999999999996
# The second moment of the uniform data about 75 is: 3962.025999999998
# The third moment of the uniform data about 75 is: -249395.69224000006
# ...

# %% [markdown]
# 4. Show:
#
#
# (a) $m_{2} = m_{2}^{'} - m_{1}^{'2}$
#
#
# (b) $m_{3} = m_{3}^{'} - 3m_{1}^{'}m_{2}^{'} + 2m_{1}^{'3}$
#
#
# (c) $ m_{4} = m_{4}^{'} - 4m_{1}^{'}m_{3}^{'} + 6m_{1}^{'2}m_{1}^{'} - 3m_{1}^{'4} $

# %%
# for normal

# a

if (round(scnd_moment_mean_normal,3) == round(scnd_moment_75_normal - ((frst_moment_75_normal**2)),3) ):
    print("a is true")
else:
    print("a is false")
    
# b 

if ( round(trd_moment_mean_normal,3) == round( trd_moment_75_normal - 3*scnd_moment_75_normal*frst_moment_75_normal + 2*frst_moment_75_normal**3, 3)):
    print("b is true")
else:
    print("b is false")

# c

if ( round(frt_moment_mean_normal, 3) == round( frt_moment_75_normal - 4*frst_moment_75_normal*trd_moment_75_normal + 6*(frst_moment_75_normal**2)*scnd_moment_75_normal - 3*frst_moment_75_normal**4 , 3) ):
    print("c is true")
else:
    print("c is false")
# Out:
# A:
#
# 8.305600000000007
# 8.305599999999984
# a is true
# b is true
# c is true

# %%
# for right skewed

# a

if (round(scnd_moment_mean_rskewed,3) == round(scnd_moment_75_rskewed - ((frst_moment_75_rskewed**2)),3) ):
    print("a is true")
else:
    print("a is false")
    
# b 

if ( round(trd_moment_mean_rskewed,3) == round( trd_moment_75_rskewed - 3*scnd_moment_75_rskewed*frst_moment_75_rskewed + 2*frst_moment_75_rskewed**3, 3)):
    print("b is true")
else:
    print("b is false")

# c

if ( round(frt_moment_mean_rskewed, 3) == round( frt_moment_75_rskewed - 4*frst_moment_75_rskewed*trd_moment_75_rskewed + 6*(frst_moment_75_rskewed**2)*scnd_moment_75_rskewed - 3*frst_moment_75_rskewed**4 , 3) ):
    print("c is true")
else:
    print("c is false")
# Out:
# a is true
# b is true
# c is true

# %%
# for left skewed

# a

if (round(scnd_moment_mean_lskewed,3) == round(scnd_moment_75_lskewed - ((frst_moment_75_lskewed**2)),3) ):
    print("a is true")
else:
    print("a is false")
    
# b 

if ( round(trd_moment_mean_lskewed,3) == round( trd_moment_75_lskewed - 3*scnd_moment_75_lskewed*frst_moment_75_lskewed + 2*frst_moment_75_lskewed**3, 3)):
    print("b is true")
else:
    print("b is false")

# c

if ( round(frt_moment_mean_lskewed, 3) == round( frt_moment_75_lskewed - 4*frst_moment_75_lskewed*trd_moment_75_lskewed + 6*(frst_moment_75_lskewed**2)*scnd_moment_75_lskewed - 3*frst_moment_75_lskewed**4 , 3) ):
    print("c is true")
else:
    print("c is false")
# Out:
# a is true
# b is true
# c is true

# %%
# for uniform

# a

if (round(scnd_moment_mean_unif,3) == round(scnd_moment_75_unif - ((frst_moment_75_unif**2)),3) ):
    print("a is true")
else:
    print("a is false")
    
# b 

if ( round(trd_moment_mean_unif,3) == round( trd_moment_75_unif - 3*scnd_moment_75_unif*frst_moment_75_unif + 2*frst_moment_75_unif**3, 3)):
    print("b is true")
else:
    print("b is false")

# c

if ( round(frt_moment_mean_unif, 3) == round( frt_moment_75_unif - 4*frst_moment_75_unif*trd_moment_75_unif + 6*(frst_moment_75_unif**2)*scnd_moment_75_unif - 3*frst_moment_75_unif**4 , 3) ):
    print("c is true")
else:
    print("c is false")
# Out:
# a is true
# b is true
# c is true
